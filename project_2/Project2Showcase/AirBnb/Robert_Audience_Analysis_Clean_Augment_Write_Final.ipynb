# %% [markdown]
# # Imports

# %%
#Enable matplotlib to display in jupyter notebook & import it
# %matplotlib inline

import matplotlib.pyplot as plt
import plotly.plotly as py
import plotly.graph_objs as go
import pandas as pd
import numpy as np
import re
from geopy.geocoders import Nominatim #used in filling missing zipcodes

# %% [markdown]
# # Read and Clean Listings.csv

# %%
#listings.csv READING

LISTINGS = 'data/listings.csv'

#Choose which columns from the csv to read in.
listings_cols = ['id',
                'host_id',
                'neighbourhood_cleansed',
                'zipcode',
                'latitude',
                'longitude',
                'property_type',
                'room_type',
                'accommodates',
                'bathrooms',
                'amenities',
                'price',
                'cleaning_fee',
                'number_of_reviews',
                'first_review',
                'review_scores_rating',
                'review_scores_accuracy',
                'review_scores_cleanliness',
                'review_scores_checkin',
                'review_scores_communication',
                'review_scores_location',
                'review_scores_value',
                'calculated_host_listings_count',
                'reviews_per_month',
                'bedrooms',
                'beds',
                'cancellation_policy',
                'instant_bookable',
                'minimum_nights'] 

#Read in data from the csv
listings = pd.read_csv(LISTINGS, usecols=listings_cols)

#Rename any Columns as needed
rename_dict = {'id':'listing_id',
              'price':'listed_price'}

listings.rename(columns = rename_dict, inplace=True)

#use listing_id as index
listings.set_index('listing_id', inplace=True)



#############################
#         Cleaning          #
#############################

# 'zipcode' ##########
#Paste this in to zipcode section of cleaning
def latLonToZip(lat, lon):
    '''Take in a latitude and longitude and return the zipcode for that location'''
    geolocator = Nominatim()
    try:
        location = geolocator.reverse(str(lat)+','+str(lon))
        z = re.compile('(\s)([0-9]{5})(,\sUnited)')
        return z.findall(location[0])[0][1]
    except:
        print(str(lat)+','+str(lon),'-----',location)
        return np.nan
    
    print(str(lat)+','+str(lon),'-----',location)
    return np.nan
#Find all missing zippcodes : missing_zipcodes
missing_zipcodes = listings[listings.zipcode.isnull()].copy()

#update rows that are missing zipcodes using latLonToZip to fill missin
listings.zipcode.update(missing_zipcodes.apply(lambda x: latLonToZip(x['latitude'], x['longitude']), axis=1))

#Remove 'zip+4' part of any zipcode 
listings.zipcode = listings.zipcode.apply(lambda x: x[:5])

# 'price' --> 'listed_price' ##########
listings.listed_price = listings.listed_price.replace('[^0-9.]+','',regex=True).astype(float)

# 'cleaning_fee' ##########
listings.cleaning_fee = listings.cleaning_fee.replace('[^0-9.]+','',regex=True).astype(float)
listings.cleaning_fee.fillna(0, inplace = True)

# 'first_review' ##########
listings.first_review = pd.to_datetime(listings.first_review)

# 'amenities' ##########
listings.amenities = listings.amenities.replace('[^\w,\s/]+','',regex=True).apply(lambda x: x.split(','))

# 'instant_bookable' ##########
listings.instant_bookable.replace({'f':False,'t':True}, inplace=True)

# %% [markdown]
# # Read and Clean Calendar.csv

# %%
#Calendar.csv READING

CALENDAR = 'data/calendar.csv'

#Read in all columns from calendar.csv : listing_id, date, available, price
calendar = pd.read_csv(CALENDAR)


#############################
#         Cleaning          #
#############################

# 'date' ##########
calendar.date = pd.to_datetime(calendar.date)

# 'available' ##########
calendar.available.replace({'f':False,'t':True}, inplace=True)

# 'price' ##########
calendar.price = calendar.price.replace('[^0-9.]+','',regex=True).astype(float)

#############################
#         Augmenting        #
#############################

#create column to represent the day of the week for each date
calendar['day_of_week'] = calendar.date.dt.dayofweek

#Fill in missing price values for each listing using mean value for day of week from that listing
calendar.price.fillna(calendar.groupby(['listing_id','day_of_week'])['price'].transform("mean"), inplace=True)

#create column for revenue generate by property (all prices for occupied days are modeled from mean)
calendar['day_revenue'] = np.where(calendar.available, 0.0, calendar.price)

#Save to Pickle because it preserves the index and types
calendar.to_pickle('data/calendar_cleaned.pkl')

# %% [markdown]
# # Using Calendar to Augment Listings DataFrame

# %%
listings = pd.read_pickle('data/listings_cleaned.pkl')
calendar = pd.read_pickle('data/calendar_cleaned.pkl')

#Create a list of calendars seperated into 4 quarters
quarter_dates = ['2016-09-06','2016-12-06','2017-03-06','2017-06-06','2017-09-06']
q_cal = [calendar[calendar.date.isin(pd.date_range(quarter_dates[n], quarter_dates[n+1]))] for n in range(4)]

#Revnue Per Quarter
for n,q in enumerate(q_cal):
    listings = listings.join(q_cal[n].groupby('listing_id').day_revenue.sum()).rename(columns={'day_revenue':'q'+str(n+1)+'_revenue'})

#Occupancy Per Quarter
for n,q in enumerate(q_cal):
    q_len = len(pd.date_range(quarter_dates[n], quarter_dates[n+1]))
    listings = listings.join((q_len - q_cal[n].groupby('listing_id').available.sum())/q_len).rename(columns={'available':'q'+str(n+1)+'_occupancy_rate'})

listings.to_pickle('data/listing_cleaned.pkl')

# %% [markdown]
# # Creating Amenities Dummy Variables

# %%
amenities = list(set([item for item_list in listings.amenities for item in item_list]))
for val in ['translation missing enhosting_amenity_49','translation missing enhosting_amenity_50', '']:
    amenities.remove(val)

amn_frame = pd.DataFrame(index = listings.index)

#create the dummy for each amenity and rename the column as you go
for amn in amenities:
    amn_frame = amn_frame.join(listings.amenities.apply(lambda amns: amn in amns)).rename(columns={'amenities':amn})

listings['analysis_table'] = listings.index
listings['analysis_table'] = pd.DataFrame(listings.analysis_table.map(lambda x: amn_frame.loc[x]))

# %%
listings['amenities'].head()
# Out:
# listing_id
# 12147973    [TV, Wireless Internet, Kitchen, Free Parking ...
# 3075044     [TV, Internet, Wireless Internet, Air Conditio...
# 6976        [TV, Cable TV, Wireless Internet, Air Conditio...
# 1436513     [TV, Internet, Wireless Internet, Air Conditio...
# 7651065     [Internet, Wireless Internet, Air Conditioning...
# Name: amenities, dtype: object

# %%
amn_frame
# Out:
#            Elevator in Building Wheelchair Accessible Hot Tub     TV  \
# listing_id
# 12147973                  False                 False   False   True
# 3075044                   False                 False   False   True
# 6976                      False                 False   False   True
# 1436513                   False                 False   False   True
# 7651065                   False                 False   False  False
# 12386020                  False                 False   False  False
# 5706985                   False                 False   False   True
# 2843445                   False                 False   False   True
# 753446                    False                 False   False  False
# 849408                    False                 False   False   True
# 12023024                  False                 False   False   True
# 1668313                   False                 False   False   True
# 2684840                   False                 False   False  False
# 13547301                  False                 False   False   True
# 5434353                   False                 False   False  False
# 225979                    False                 False   False   True
# 3420384                   False                 False    True   True
# 13512930                  False                 False   False   True
# 7482195                   False                 False   False  False
# 7252607                   False                 False   False   True
# 2583074                   False                 False   False  False
# 13251243                  False                 False   False   True
# 225834                    False                 False   False   True
# 6400432                   False                 False   False   True
# 5498472                   False                 False   False   True
# 894539                    False                 False   False   True
# 879929                    False                 False   False  False
# 9218312                   False                 False   False  False
# 321328                    False                 False   False  False
# 1810172                   False                 False   False   True
# ...                         ...                   ...     ...    ...
# 13015653                  False                 False    True  False
# 14849141                  False                 False   False  False
# 14604429                  False                 False   False  False
# 14592644                  False                 False   False   True
# 12915510                  False                 False   False   True
# 14887382                  False                 False   False  False
# 14823430                  False                 False   False  False
# 14881840                  False                 False   False   True
# 11452297                  False                 False   False   True
# 14576706                  False                 False   False  False
# 14335003                  False                 False   False  False
# 14871445                  False                 False   False   True
# 14472678                  False                 False   False   True
# 14574800                  False                 False   False  False
# 14426586                  False                 False   False   True
# 3131519                   False                 False   False   True
# 14592547                  False                 False   False  False
# 14744740                  False                 False   False   True
# 14504583                  False                 False   False  False
# 14743129                  False                 False   False  False
# 5280827                   False                 False   False  False
# 14689681                  False                 False   False  False
# 13750763                  False                 False   False   True
# 14536322                  False                 False   False   True
# 14852179                  False                 False   False   True
# 8373729                   False                 False   False  False
# 14844274                   True                 False   False   True
# 14585486                  False                 False   False  False
# 14603878                  False                 False   False  False
# 14504422                  False                 False   False  False
#
#            Paid Parking Off Premises Washer / Dryer Essentials   Dogs  \
# listing_id
# 12147973                       False          False       True   True
# 3075044                        False          False       True   True
# 6976                           False          False       True  False
# 1436513                        False          False       True  False
# 7651065                        False          False       True  False
# 12386020                       False          False      False  False
# 5706985                        False          False       True  False
# 2843445                        False          False       True   True
# 753446                         False          False      False  False
# 849408                         False          False       True  False
# 12023024                       False          False       True  False
# 1668313                        False          False      False  False
# 2684840                        False          False       True   True
# 13547301                       False          False       True  False
# 5434353                        False          False       True  False
# 225979                         False          False       True  False
# 3420384                        False          False      False  False
# 13512930                       False          False       True  False
# 7482195                        False          False       True  False
# 7252607                        False          False       True  False
# 2583074                        False          False       True  False
# 13251243                       False          False       True  False
# 225834                         False          False       True  False
# 6400432                        False          False      False  False
# 5498472                        False          False       True  False
# 894539                         False          False       True  False
# 879929                         False          False      False  False
# 9218312                        False          False       True  False
# 321328                         False          False      False  False
# 1810172                        False          False       True  False
# ...                              ...            ...        ...    ...
# 13015653                       False          False       True  False
# 14849141                       False          False       True  False
# 14604429                       False          False       True  False
# 14592644                       False          False       True  False
# 12915510                       False          False       True   True
# 14887382                       False          False       True  False
# 14823430                       False          False       True  False
# 14881840                       False          False       True  False
# 11452297                       False          False       True  False
# 14576706                       False          False       True  False
# 14335003                       False          False       True  False
# 14871445                       False          False       True  False
# 14472678                       False          False       True  False
# 14574800                       False          False       True  False
# 14426586                       False          False       True  False
# 3131519                        False          False       True  False
# 14592547                       False          False       True  False
# 14744740                       False          False       True  False
# 14504583                       False          False       True  False
# 14743129                       False          False       True  False
# 5280827                        False          False       True  False
# 14689681                       False          False       True  False
# 13750763                       False          False       True  False
# 14536322                       False          False       True  False
# 14852179                       False          False       True  False
# 8373729                        False          False       True  False
# 14844274                       False          False       True  False
# 14585486                       False          False      False  False
# 14603878                       False          False       True  False
# 14504422                       False          False       True  False
#
#            Internet Lock on Bedroom Door   ...   Hangers First Aid Kit  \
# listing_id                                 ...
# 12147973      False                False   ...     False         False
# 3075044        True                 True   ...      True         False
# 6976          False                 True   ...     False          True
# 1436513        True                False   ...      True          True
# 7651065        True                False   ...      True          True
# 12386020      False                False   ...      True         False
# 5706985        True                False   ...     False          True
# 2843445        True                False   ...      True          True
# 753446        False                False   ...      True         False
# 849408         True                False   ...      True          True
# 12023024      False                 True   ...     False         False
# 1668313        True                False   ...     False         False
# 2684840       False                False   ...     False         False
# 13547301       True                False   ...      True          True
# 5434353        True                False   ...     False          True
# 225979         True                False   ...     False          True
# 3420384        True                False   ...     False          True
# 13512930      False                 True   ...      True         False
# 7482195        True                False   ...     False         False
# 7252607        True                False   ...     False         False
# 2583074        True                False   ...     False          True
# 13251243       True                False   ...      True          True
# 225834         True                False   ...     False          True
# 6400432        True                False   ...     False          True
# 5498472        True                False   ...     False         False
# 894539         True                False   ...      True          True
# 879929         True                False   ...     False         False
# 9218312       False                False   ...      True          True
# 321328         True                False   ...     False         False
# 1810172        True                False   ...     False         False
# ...             ...                  ...   ...       ...           ...
# 13015653      False                False   ...      True         False
# 14849141      False                False   ...      True         False
# 14604429      False                False   ...      True          True
# 14592644       True                False   ...      True         False
# 12915510       True                False   ...     False          True
# 14887382      False                False   ...      True         False
# 14823430       True                False   ...      True         False
# 14881840       True                False   ...     False         False
# 11452297       True                False   ...      True         False
# 14576706       True                 True   ...      True         False
# 14335003      False                False   ...      True         False
# 14871445      False                False   ...     False         False
# 14472678       True                False   ...      True         False
# 14574800      False                 True   ...      True         False
# 14426586       True                False   ...     False         False
# 3131519        True                False   ...     False         False
# 14592547      False                 True   ...      True          True
# 14744740       True                False   ...      True         False
# 14504583      False                False   ...     False         False
# 14743129      False                False   ...      True         False
# 5280827        True                 True   ...      True          True
# 14689681      False                False   ...      True         False
# 13750763      False                 True   ...      True         False
# 14536322       True                False   ...      True         False
# 14852179       True                 True   ...      True          True
# 8373729        True                 True   ...      True         False
# 14844274       True                False   ...      True         False
# 14585486      False                False   ...     False         False
# 14603878      False                False   ...      True         False
# 14504422      False                False   ...     False         False
#
#            Wireless Internet Indoor Fireplace Free Parking on Premises  \
# listing_id
# 12147973                True            False                     True
# 3075044                 True            False                    False
# 6976                    True            False                     True
# 1436513                 True             True                     True
# 7651065                 True            False                    False
# 12386020                True            False                     True
# 5706985                 True            False                     True
# 2843445                 True             True                     True
# 753446                  True            False                    False
# 849408                  True            False                     True
# 12023024                True            False                     True
# 1668313                 True            False                     True
# 2684840                 True            False                     True
# 13547301                True            False                     True
# 5434353                 True            False                     True
# 225979                  True            False                     True
# 3420384                 True             True                     True
# 13512930                True            False                     True
# 7482195                 True            False                     True
# 7252607                 True             True                     True
# 2583074                 True            False                    False
# 13251243                True            False                    False
# 225834                  True            False                     True
# 6400432                 True             True                     True
# 5498472                 True             True                     True
# 894539                  True             True                     True
# 879929                  True            False                     True
# 9218312                 True            False                     True
# 321328                  True            False                    False
# 1810172                 True            False                     True
# ...                      ...              ...                      ...
# 13015653               False             True                    False
# 14849141                True            False                     True
# 14604429                True            False                    False
# 14592644                True            False                    False
# 12915510                True            False                    False
# 14887382                True            False                     True
# 14823430                True            False                    False
# 14881840                True            False                    False
# 11452297                True            False                     True
# 14576706                True            False                     True
# 14335003                True            False                     True
# 14871445                True            False                    False
# 14472678                True            False                    False
# 14574800                True            False                     True
# 14426586                True             True                     True
# 3131519                 True            False                    False
# 14592547                True            False                    False
# 14744740                True            False                    False
# 14504583                True            False                    False
# 14743129                True            False                     True
# 5280827                 True            False                     True
# 14689681               False             True                    False
# 13750763                True            False                    False
# 14536322                True            False                    False
# 14852179                True            False                    False
# 8373729                 True            False                     True
# 14844274                True            False                     True
# 14585486               False            False                    False
# 14603878               False            False                    False
# 14504422                True            False                    False
#
#            Family/Kid Friendly Smoke Detector Cable TV Hair Dryer Kitchen
# listing_id
# 12147973                  True           True    False      False    True
# 3075044                   True           True    False       True    True
# 6976                     False           True     True      False    True
# 1436513                  False           True    False       True    True
# 7651065                  False           True    False       True    True
# 12386020                  True           True     True      False    True
# 5706985                  False           True    False      False    True
# 2843445                  False           True    False       True   False
# 753446                    True           True    False       True   False
# 849408                    True           True     True       True    True
# 12023024                  True           True    False       True    True
# 1668313                  False          False     True      False   False
# 2684840                   True           True     True       True    True
# 13547301                  True           True    False       True    True
# 5434353                  False           True    False      False    True
# 225979                   False           True    False      False    True
# 3420384                   True           True     True      False    True
# 13512930                 False           True    False       True    True
# 7482195                  False           True     True      False    True
# 7252607                  False           True    False      False    True
# 2583074                  False           True    False      False    True
# 13251243                  True           True    False       True   False
# 225834                   False           True    False      False    True
# 6400432                   True           True    False      False    True
# 5498472                   True           True     True      False    True
# 894539                    True           True     True       True    True
# 879929                   False          False    False      False    True
# 9218312                  False           True    False      False   False
# 321328                    True          False    False      False    True
# 1810172                   True           True     True      False   False
# ...                        ...            ...      ...        ...     ...
# 13015653                  True           True    False      False    True
# 14849141                  True           True    False       True    True
# 14604429                  True           True    False       True    True
# 14592644                  True           True     True       True    True
# 12915510                 False           True    False       True    True
# 14887382                  True           True    False       True    True
# 14823430                 False           True    False       True   False
# 14881840                 False          False    False      False    True
# 11452297                  True           True     True      False    True
# 14576706                  True           True    False       True    True
# 14335003                 False          False    False      False    True
# 14871445                 False           True    False      False   False
# 14472678                  True           True     True       True    True
# 14574800                  True           True    False       True    True
# 14426586                 False           True    False      False    True
# 3131519                  False          False     True      False    True
# 14592547                 False           True    False       True    True
# 14744740                  True           True     True       True    True
# 14504583                 False          False    False      False    True
# 14743129                  True           True    False       True    True
# 5280827                   True           True    False       True    True
# 14689681                 False           True    False       True    True
# 13750763                  True           True    False       True   False
# 14536322                 False           True    False       True    True
# 14852179                 False           True     True       True    True
# 8373729                   True           True    False       True    True
# 14844274                  True           True    False       True    True
# 14585486                 False          False    False      False   False
# 14603878                  True          False    False      False    True
# 14504422                 False          False    False      False    True
#
# [3585 rows x 43 columns]

# %% [markdown]
# # Creating Other Dummy Variables

# %%
#Taking
other_dummies = pd.DataFrame()
for i in ['instant_bookable', 'cancellation_policy', 'property_type', 'room_type']:
    other_dummies = pd.concat([other_dummies, pd.get_dummies(listings[i])], axis = 1)

#Other dummy Name Columns
c1 = [''.join(['instant_bookable_', str(other_dummies.columns[i]).strip()]) for i in range(0,2)]
c2 = [''.join(['cancel_pol_', str(other_dummies.columns[i]).strip()]) for i in range(2,6)]
c3 = [''.join(['Prop_type_', str(other_dummies.columns[i]).strip()]) for i in range(6,19)]
c4 = [''.join(['Room_type_', str(other_dummies.columns[i]).strip()]) for i in range(19,22)]

odc = c1 + c2 + c3 + c4
other_dummies.columns = odc
other_dummies.head()
# Out:
#             instant_bookable_False  instant_bookable_True  \
# listing_id
# 12147973                       1.0                    0.0
# 3075044                        0.0                    1.0
# 6976                           1.0                    0.0
# 1436513                        1.0                    0.0
# 7651065                        1.0                    0.0
#
#             cancel_pol_flexible  cancel_pol_moderate  cancel_pol_strict  \
# listing_id
# 12147973                    0.0                  1.0                0.0
# 3075044                     0.0                  1.0                0.0
# 6976                        0.0                  1.0                0.0
# 1436513                     0.0                  1.0                0.0
# 7651065                     1.0                  0.0                0.0
#
#             cancel_pol_super_strict_30  Prop_type_Apartment  \
# listing_id
# 12147973                           0.0                  0.0
# 3075044                            0.0                  1.0
# 6976                               0.0                  1.0
# 1436513                            0.0                  0.0
# 7651065                            0.0                  0.0
#
#             Prop_type_Bed & Breakfast  Prop_type_Boat  Prop_type_Camper/RV  \
# listing_id
# 12147973                          0.0             0.0                  0.0
# 3075044                           0.0             0.0                  0.0
# 6976                              0.0             0.0                  0.0
# 1436513                           0.0             0.0                  0.0
# 7651065                           0.0             0.0                  0.0
#
#                     ...            Prop_type_Entire Floor  \
# listing_id          ...
# 12147973            ...                               0.0
# 3075044             ...                               0.0
# 6976                ...                               0.0
# 1436513             ...                               0.0
# 7651065             ...                               0.0
#
#             Prop_type_Guesthouse  Prop_type_House  Prop_type_Loft  \
# listing_id
# 12147973                     0.0              1.0             0.0
# 3075044                      0.0              0.0             0.0
# 6976                         0.0              0.0             0.0
# 1436513                      0.0              1.0             0.0
# 7651065                      0.0              1.0             0.0
#
#             Prop_type_Other  Prop_type_Townhouse  Prop_type_Villa  \
# listing_id
# 12147973                0.0                  0.0              0.0
# 3075044                 0.0                  0.0              0.0
# 6976                    0.0                  0.0              0.0
# 1436513                 0.0                  0.0              0.0
# 7651065                 0.0                  0.0              0.0
#
#             Room_type_Entire home/apt  Room_type_Private room  \
# listing_id
# 12147973                          1.0                     0.0
# 3075044                           0.0                     1.0
# 6976                              0.0                     1.0
# 1436513                           0.0                     1.0
# 7651065                           0.0                     1.0
#
#             Room_type_Shared room
# listing_id
# 12147973                      0.0
# 3075044                       0.0
# 6976                          0.0
# 1436513                       0.0
# 7651065                       0.0
#
# [5 rows x 22 columns]

# %%
#Important KPI metrics have ~20% Nas
kpi = ['reviews_per_month', 'review_scores_rating', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location']
Review_Score_NA = pd.DataFrame([[x, listings[x].isnull().sum()/len(listings[x])] for x in kpi])
Review_Score_NA.columns =['review_score_metrics', '%_of_column_NA']
Review_Score_NA
# Out:
#           review_score_metrics  %_of_column_NA
# 0            reviews_per_month        0.210879
# 1         review_scores_rating        0.226778
# 2       review_scores_accuracy        0.229568
# 3    review_scores_cleanliness        0.228173
# 4        review_scores_checkin        0.228731
# 5  review_scores_communication        0.228173
# 6       review_scores_location        0.229289

# %% [markdown]
# # Subsetting By Audience

# %%
#Creating a specific subset of columns as attributes to analyze between audiences
audienceData = ['accommodates', 'bathrooms', 'bedrooms', 'beds', 'listed_price', \
                'cleaning_fee', 'minimum_nights', 'number_of_reviews', 'review_scores_rating', \
                'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', \
                'review_scores_communication', 'review_scores_location', 'review_scores_value', \
                'calculated_host_listings_count', 'reviews_per_month']

# %% [markdown]
# # Merging Dataframes

# %%
#Audience is a dataframe used for audience analysis, concatenated from listings & dummies
audience = pd.concat([listings[audienceData], other_dummies, amn_frame], axis=1)

#Creating Audience Segmentation variables defined based on the calculated host listings count
audience['user_type'] = audience.calculated_host_listings_count.apply(lambda x:  'Sharers' if x <= 2 else 'Businesses')
audience['user_count'] = 1

audience.select_dtypes(include=['bool']).astype(int, inplace = True)
audience.columns = [i.replace(" ", "_") for i in audience.columns]
audience.head()
# Out:
#             accommodates  bathrooms  bedrooms  beds  listed_price  \
# listing_id
# 12147973               4        1.5       2.0   3.0         250.0
# 3075044                2        1.0       1.0   1.0          65.0
# 6976                   2        1.0       1.0   1.0          65.0
# 1436513                4        1.0       1.0   2.0          75.0
# 7651065                2        1.5       1.0   2.0          79.0
#
#             cleaning_fee  minimum_nights  number_of_reviews  \
# listing_id
# 12147973            35.0               2                  0
# 3075044             10.0               2                 36
# 6976                 NaN               3                 41
# 1436513             50.0               1                  1
# 7651065             15.0               2                 29
#
#             review_scores_rating  review_scores_accuracy     ...      \
# listing_id                                                   ...
# 12147973                     NaN                     NaN     ...
# 3075044                     94.0                    10.0     ...
# 6976                        98.0                    10.0     ...
# 1436513                    100.0                    10.0     ...
# 7651065                     99.0                    10.0     ...
#
#             Wireless_Internet  Indoor_Fireplace  Free_Parking_on_Premises  \
# listing_id
# 12147973                 True             False                      True
# 3075044                  True             False                     False
# 6976                     True             False                      True
# 1436513                  True              True                      True
# 7651065                  True             False                     False
#
#             Family/Kid_Friendly  Smoke_Detector  Cable_TV  Hair_Dryer  \
# listing_id
# 12147973                   True            True     False       False
# 3075044                    True            True     False        True
# 6976                      False            True      True       False
# 1436513                   False            True     False        True
# 7651065                   False            True     False        True
#
#             Kitchen  user_type  user_count
# listing_id
# 12147973       True    Sharers           1
# 3075044        True    Sharers           1
# 6976           True    Sharers           1
# 1436513        True    Sharers           1
# 7651065        True    Sharers           1
#
# [5 rows x 85 columns]

# %% [markdown]
# # Audience Attributes

# %%
#For the variables of interest that should be averaged per listing ID
audienceUser = audience.groupby('user_type', as_index = False)['user_count'].sum()
audienceMeanValues = audience.groupby('user_type', as_index = False)[list(audience.columns[0:15])].mean().round(2)
audienceMeans = pd.merge(audienceUser, audienceMeanValues, on = 'user_type').T
audienceMeans
# Out:
#                                       0        1
# user_type                    Businesses  Sharers
# user_count                         1351     2234
# accommodates                       3.29     2.89
# bathrooms                          1.33     1.16
# bedrooms                            1.3     1.23
# beds                               1.69     1.56
# listed_price                     185.66   166.83
# cleaning_fee                      86.51    54.07
# minimum_nights                     4.01     2.67
# number_of_reviews                 21.13    17.78
# review_scores_rating              89.67    93.25
# review_scores_accuracy             9.19     9.57
# review_scores_cleanliness          9.17     9.31
# review_scores_checkin              9.44     9.77
# review_scores_communication        9.43     9.78
# review_scores_location             9.27      9.5
# review_scores_value                 8.9     9.33

# %%
#For the variables of interest that should be summed, and then calculated as a % of user_type
audienceSumValues = audience.groupby('user_type', as_index = False)[list(audience.columns[17:84])].sum()
audienceSums = pd.merge(audienceUser, audienceSumValues, on = 'user_type')
audienceSums.ix[2, :] = audienceSums.sum()
audienceSums.ix[2, 0] = 'Total'
audienceSums.ix[0, 2:] = audienceSums.ix[0, 2:]/audienceSums.ix[0, 1]
audienceSums.ix[1, 2:] = audienceSums.ix[1, 2:]/audienceSums.ix[1, 1]
audienceSums.round(2).T
# Out:
#                                                    0        1      2
# user_type                                 Businesses  Sharers  Total
# user_count                                      1351     2234   3585
# instant_bookable_False                          0.78     0.86   2991
# instant_bookable_True                           0.22     0.14    594
# cancel_pol_flexible                             0.11     0.38    999
# cancel_pol_moderate                              0.2     0.29    919
# cancel_pol_strict                               0.63     0.33   1582
# cancel_pol_super_strict_30                      0.06        0     85
# Prop_type_Apartment                             0.74     0.72   2612
# Prop_type_Bed_&_Breakfast                       0.02     0.01     41
# Prop_type_Boat                                  0.01        0     12
# Prop_type_Camper/RV                                0        0      1
# Prop_type_Condominium                           0.04     0.08    231
# Prop_type_Dorm                                     0        0      2
# Prop_type_Entire_Floor                             0        0      4
# Prop_type_Guesthouse                               0        0      1
# Prop_type_House                                 0.16     0.15    562
# Prop_type_Loft                                     0     0.01     39
# Prop_type_Other                                 0.01        0     17
# Prop_type_Townhouse                             0.01     0.02     54
# Prop_type_Villa                                    0        0      6
# Room_type_Entire_home/apt                       0.66     0.56   2127
# Room_type_Private_room                          0.33     0.41   1378
# Room_type_Shared_room                           0.01     0.03     80
# Elevator_in_Building                            0.32     0.19    868
# Wheelchair_Accessible                           0.03     0.05    148
# Hot_Tub                                         0.04     0.05    167
# TV                                              0.78      0.7   2607
# Paid_Parking_Off_Premises                          0        0      4
# Washer_/_Dryer                                     0        0      2
# ...                                              ...      ...    ...
# 24Hour_Checkin                                  0.42     0.31   1247
# Buzzer/Wireless_Intercom                        0.18     0.27    839
# Cats                                            0.04     0.06    181
# Doorman                                         0.12     0.05    268
# Safety_Card                                     0.11     0.14    458
# Pets_live_on_this_property                      0.07     0.15    429
# Pets_Allowed                                    0.13     0.14    486
# Suitable_for_Events                             0.03     0.04    138
# Heating                                         0.96     0.94   3384
# Carbon_Monoxide_Detector                        0.65      0.7   2442
# Iron                                            0.56     0.48   1828
# Shampoo                                         0.68     0.67   2421
# Washer                                           0.7     0.68   2475
# Other_pets                                         0        0     16
# Breakfast                                       0.06      0.1    316
# Smoking_Allowed                                 0.01     0.04     95
# Air_Conditioning                                0.85     0.75   2821
# translation_missing_enhosting_amenity_50        0.17     0.16    581
# Free_Parking_on_Street                             0        0      9
# Fire_Extinguisher                               0.39     0.47   1582
# Hangers                                         0.57     0.54   1985
# First_Aid_Kit                                   0.23     0.34   1063
# Wireless_Internet                               0.97     0.94   3421
# Indoor_Fireplace                                0.09     0.12    393
# Free_Parking_on_Premises                        0.18     0.26    831
# Family/Kid_Friendly                             0.61     0.47   1888
# Smoke_Detector                                  0.74     0.86   2911
# Cable_TV                                        0.64     0.41   1770
# Hair_Dryer                                      0.54     0.48   1811
# Kitchen                                         0.92     0.91   3284
#
# [68 rows x 3 columns]
